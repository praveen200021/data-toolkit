# %% [markdown]
# 1. What is NumPy, and why is it widely used in Python.
#
#   sol:NumPy is a fundamental library in Python for scientific computing. It offers powerful features for working with multidimensional arrays and performing various mathematical operations efficiently.
#
# * NumPy (Numerical Python) is an open source Python library that has a wide range of inbuilt functions.
#
#
# ---
#
#
# 2. How does broadcasting work in NumPy.
#
#   sol:Broadcasting is a mechanism in NumPy that allows performing operations on arrays of different shapes under certain conditions. When operands have different shapes, NumPy expands the smaller array to match the larger one in a specific way to perform element-wise operations.
#
# ---
#
#
# 3. What is a Pandas DataFrame.
#
#   sol:A Pandas DataFrame is a 2-dimensional labeled data structure in Python, similar to a table in a database, an Excel spreadsheet, or a data frame in R.
#
# ---
#
#
# 4. Explain the use of the groupby() method in Pandas.
#
#   sol:The groupby() method in Pandas is used to group rows of data based on the values in one or more columns, and then perform aggregate operations (like sum, mean, count, etc.) on those groups.
#
# ---
#
#
#
# 5. Why is Seaborn preferred for statistical visualizations.
#
#   sol:Seaborn is preferred for statistical visualizations in Python because it’s built specifically to make complex visualizations simple, attractive, and informative, especially for data analysis and statistical relationships.
#
#
# ---
#
#
# 6. What are the differences between NumPy arrays and Python lists.
#
#   sol:NumPy arrays are faster, more memory-efficient, and support advanced mathematical operations, while Python lists are more flexible but slower and less suitable for numerical computing.
#
#
# ---
#
#
# 7. What is a heatmap, and when should it be used.
#
#   sol:A **heatmap** is a data visualization that uses **color to represent values in a matrix**, making it ideal for spotting patterns, correlations, or intensities in **2D data like correlation matrices or pivot tables**.
#
#
# ---
#
# 8. What does the term “vectorized operation” mean in NumPy.
#
#   sol:A **vectorized operation** in NumPy refers to performing operations on **entire arrays without using explicit loops**, making the code faster, cleaner, and more efficient by leveraging optimized low-level implementations.
#
# ---
#
# 9. How does Matplotlib differ from Plotly.
#
#   sol:**Matplotlib** is a static plotting library ideal for traditional, publication-quality charts, while **Plotly** creates interactive, web-friendly visualizations with features like zoom, hover, and tooltips.
#
# ---
#
#
# 10.  What is the significance of hierarchical indexing in Pandas.
#
#   sol:**Hierarchical indexing** in Pandas allows you to create **multiple levels of indexes** on rows and/or columns, enabling more **complex data organization**, **easier subsetting**, and **better handling of multi-dimensional data** in a **2D DataFrame** or **Series**. It simplifies operations on multi-level data, like grouping or aggregating, without losing the hierarchical structure.
#
# ---
#
#
# 11. What is the role of Seaborn’s pairplot() function.
#
#   sol:The **`pairplot()`** function in Seaborn creates a **grid of scatter plots** for all pairs of numerical variables in a dataset, along with **histograms or density plots** on the diagonal to visualize the distribution of individual variables. It's used to explore relationships and correlations between multiple variables at once.
#
# ---
#
#
# 12. What is the purpose of the describe() function in Pandas.
#
#   sol:The **`describe()`** function in Pandas provides **summary statistics** for numerical columns in a DataFrame or Series, including measures like **count**, **mean**, **standard deviation**, **min/max**, and **quantiles** (25th, 50th, and 75th percentiles), offering a quick overview of the data's distribution and spread.
#
# ---
#
#
# 13. Why is handling missing data important in Pandas.
#
#   sol:Handling missing data in Pandas is important because **missing values can distort analysis**, lead to **incorrect conclusions**, and **impact model performance**. Properly handling missing data through techniques like imputation or removal ensures **data integrity**, **accurate analyses**, and **reliable machine learning models**.
#
# ---
#
#
# 14. What are the benefits of using Plotly for data visualization.
#
#   sol:Plotly offers interactive, web-friendly visualizations with extensive customization options, making it ideal for creating dynamic, detailed charts that enhance user engagement and analysis.
#
# ---
#
#
# 15. How does NumPy handle multidimensional arrays.
#
#   sol:NumPy handles multidimensional arrays using its **ndarray** object, which supports efficient storage and manipulation of data in **n-dimensional grids**, allowing for operations like slicing, broadcasting, and element-wise operations across multiple dimensions.
#
# ---
#
#
# 16. What is the role of Bokeh in data visualization.
#
#   sol:Bokeh is used in data visualization to create **interactive, web-ready plots** and dashboards with high-performance rendering, making it ideal for **real-time visualizations**, **large datasets**, and **dynamic applications** in web environments.
#
# ---
#
#
# 17. Explain the difference between apply() and map() in Pandas.
#
#   sol:`apply()` is used for applying a function along an axis of a DataFrame or Series, while `map()` is used for element-wise transformations in a Series, typically for simple mappings or replacements.
#
# ---
#
#
# 18. What are some advanced features of NumPy.
#
#   sol:Advanced features of NumPy include **broadcasting** (performing operations on arrays of different sizes), **advanced indexing** (using fancy indexing like boolean or integer indexing), **linear algebra** (matrix operations), **random number generation**, and **vectorization** (efficient operations on arrays without loops).
#
# ---
#
#
# 19. How does Pandas simplify time series analysis.
#
#   sol:Pandas simplifies time series analysis by providing **easy-to-use tools for handling dates and times**, such as **datetime indexing**, **resampling**, **shifting**, **time-based grouping**, and **rolling window calculations**, making it easier to analyze trends, seasonality, and time-dependent data.
#
# ---
#
#
# 20. What is the role of a pivot table in Pandas.
#
#   sol:A **pivot table** in Pandas is used to **summarize and aggregate data** by transforming long-format data into a more organized, multi-dimensional table, allowing for easy analysis of relationships between variables, typically with operations like **mean**, **sum**, or **count**.
#
# ---
#
#
#
# 21. Why is NumPy’s array slicing faster than Python’s list slicing.
#
#   sol:NumPy's array slicing is faster than Python's list slicing because **NumPy arrays are implemented in C** and allow for **contiguous memory allocation**, enabling efficient low-level operations, while Python lists involve **additional overhead** due to dynamic resizing and more complex data management.
#
# ---
#
#
# 23. What are some common use cases for Seaborn.
#
#   sol:Seaborn is commonly used for **exploratory data analysis**, **statistical visualizations**, and **categorical data visualization**, providing easy-to-create plots like **scatter plots**, **box plots**, and **heatmaps** to explore relationships and distributions in datasets.

# %%
# .1 How do you create a 2D NumPy array and calculate the sum of each row
import numpy as np
n=np.array([[1,2,3],[1,1,1],[1,2,3]])

print(n.sum(axis=1))
# Out:
# [6 3 6]

# %%
#2. Write a Pandas script to find the mean of a specific column in a DataFrame
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'Salary': [50000, 55000, 60000, 65000]
}
df=pd.DataFrame(data)
mean=df['Salary'].mean()
print(int(mean))
# Out:
# 57500

# %%
#3.Create a scatter plot using Matplotlib
import matplotlib.pyplot as plt


x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]


plt.scatter(x, y)


plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Scatter Plot')


plt.show()

# %%
# 4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [2, 3, 4, 5, 6]
}

df = pd.DataFrame(data)

# Calculate the correlation matrix
corr_matrix = df.corr()

# Visualize the correlation matrix with a heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')

# Show the plot
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#5.Generate a bar plot using Plotly
import plotly.express as px

# Sample data
data = {'Category': ['A', 'B', 'C'], 'Value': [10, 15, 20]}

# Create a DataFrame
import pandas as pd
df = pd.DataFrame(data)

# Create a bar plot
fig = px.bar(df, x='Category', y='Value', title='Bar Plot using Plotly')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#6. Create a DataFrame and add a new column based on an existing column
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'Salary': [50000, 55000, 60000, 65000]

}
df=pd.DataFrame(data)
df['square']=df['Salary']*2
print(df)
# Out:
#       Name  Age  Salary  square
# 0    Alice   25   50000  100000
# 1      Bob   30   55000  110000
# 2  Charlie   35   60000  120000
# 3    David   40   65000  130000

# %%
#7. Write a program to perform element-wise multiplication of two NumPy arrays.
import numpy as np
arr1=np.array([1,2,0])
arr2=np.array([3,2,4])

result=np.multiply(arr1,arr2)
print(result)
# Out:
# [3 4 0]

# %%
#8. Create a line plot with multiple lines using Matplotlib
import matplotlib.pyplot as plt

# Sample data for multiple lines
x = [0, 1, 2, 3, 4]
y1 = [0, 1, 4, 9, 16]
y2 = [0, 1, 2, 3, 4]
y3 = [0, -1, -2, -3, -4]

# Create a line plot with multiple lines
plt.plot(x, y1, label='y = x^2', marker='o')
plt.plot(x, y2, label='y = x', marker='s')
plt.plot(x, y3, label='y = -x', marker='^')

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot with Multiple Lines')

# Displaying the legend
plt.legend()

# Show the plot
plt.show()

# %%
#9. Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold
import pandas as pd
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'Salary': [50000, 55000, 60000, 65000, 70000]
}

df = pd.DataFrame(data)


threshold_age = 35
filtered_df = df[df['Age'] > threshold_age]

print(filtered_df)
# Out:
#     Name  Age  Salary
# 3  David   40   65000
# 4    Eva   45   70000

# %%
#10.Create a histogram using Seaborn to visualize a distribution
import seaborn as sns
import matplotlib.pyplot as plt

data = [12, 15, 13, 17, 19, 18, 21, 22, 23, 25, 24, 26, 28, 30]

sns.histplot(data, bins=8, kde=True, color='skyblue')
plt.title('Distribution Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
#11. Perform matrix multiplication using NumPyA
import numpy as np

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

result = np.matmul(A, B)
print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
#12.Use Pandas to load a CSV file and display its first 5 rows
import pandas as pd

df = pd.read_csv('your_file.csv')
print(df.head())

# %%
#13.Create a 3D scatter plot using Plotly.
import plotly.express as px
import pandas as pd

# Sample 3D data
data = {
    'X': [1, 2, 3, 4, 5],
    'Y': [10, 15, 13, 17, 19],
    'Z': [5, 6, 7, 8, 9]
}

df = pd.DataFrame(data)

# Create a 3D scatter plot
fig = px.scatter_3d(df, x='X', y='Y', z='Z', title='3D Scatter Plot')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
